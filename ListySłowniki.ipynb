# %%
fruits = ["jabłko", "banan", "malina"]

# dodajemy nowy owoc
fruits.append("gruszka")
print("Lista po dodaniu nowego owocu:", fruits)
# Out:
# Lista po dodaniu nowego owocu: ['jabłko', 'banan', 'malina', 'gruszka']

# %%
second_fruit = fruits[1]  # indeksowanie od 0
print("Drugi owoc na liście:", second_fruit)
# Out:
# Drugi owoc na liście: banan

# %%
numbers_list = [4, 8, 15, 16, 23, 42]
average = sum(numbers_list) / len(numbers_list)
print("Średnia z listy:", average)
# Out:
# Średnia z listy: 18.0

# %%
person = {"name": "Ala", "age": 22}

for key, value in person.items():
    print(f"{key}: {value}")
# Out:
# name: Ala
# age: 22
