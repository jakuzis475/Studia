# %%
import numpy as np
import pandas as pd

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

# %%
sum_ab = a + b
print("a + b =", sum_ab)
# Out:
# a + b = [5 7 9]

# %%
dot_ab = np.dot(a, b)
print("a · b =", dot_ab)
# Out:
# a · b = 32
